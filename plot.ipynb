# %%
from phase.potts.notebook_plots import list_sampling_sources, show_sampling_report

summary = "/home/angiod@usi.ch/PHASE/data/projects/a2a/systems/api/clusters/8591c3da-34ef-4c58-92be-26fb3aa3532b/samples/sampling_20260203_100009/run_summary.npz"

# inspect available sources
sources = list_sampling_sources(summary)
sources["md_sources"]      # [{'id': '...', 'label': '...', 'type': '...', 'count': ...}, ...]
sources["sample_sources"]  # same structure

# show only MD Active vs Gibbs (example ids)
show_sampling_report(
    summary,
    md_source_ids=["state:Active"],     # replace with actual md_source id(s)
    sample_source_ids=["gibbs"],  # replace with actual sample id(s)
    offline=False,
)
