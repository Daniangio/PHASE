# %%
import sys
from alloskin.simulation.main import main

sys.argv = [
    '',
    '--npz', '/home/angiod@usi.ch/AllosKin/FApo_m0-FApo_m1-INApo_m0-INApo_m1_clusters_20251215T174417.npz',
    '--fit', 'plm',
    '--gibbs-samples', '500',
    '--gibbs-burnin', '500',
    '--sa-reads', '2000',
    '--sa-sweeps', '5',
    '--plot', 'marginals.html',
    '--no-annotate'
]
main()
# Out:
# [data] T=1002  N=300  edges=3020
# [plm] epoch    1/200  avg_loss=2976.841264
