# %%
import sys
from alloskin.simulation.main import main

sys.argv = [
    '',
    '--npz', '/scratch/angiod/Quantum/FApo_m0-FApo_m1-INApo_m0-INApo_m1_clusters_20251215T174417.npz',
    '--fit', 'pmi+plm',
    '--gibbs-method', 'rex', # 'single'
    # Gibbs
    # '--gibbs-samples', '500',
    # '--gibbs-burnin', '500',
    # '--gibbs-thin', '2',
    # Replica exchange
    '--rex-beta-min', '0.2',
    '--rex-beta-max', '1.2',
    '--rex-n-replicas', '12',
    '--rex-spacing', 'geom',
    '--rex-rounds', '4000',
    '--rex-burnin-rounds', '1000',
    # Simulated Annealing
    '--beta', '1',
    '--sa-reads', '2000',
    '--sa-sweeps', '2000',
    '--estimate-beta-eff',
    '--beta-eff-w-marg', '1.0',
    '--beta-eff-w-pair', '1.0',
    # Plotting and progress
    '--beta-eff-plot', 'results/beta_scan.html',
    '--plot-path', 'results/marginals.html',
    '--progress'
]

main()
